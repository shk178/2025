# %% [markdown]
# `새롭게 나타난 현상을 검토해 기존 분류를 이용해 정의된 집합에 배정하는 것으로, 의사결정 나무 기법을 사용하는 데이터 마이닝 기법은`
# #### 분류classification

# %% [markdown]
# `수입수준신용카드잔고 등 연속된 변수의 값을 추정하는데 사용되며 신경망 모형 기법을 사용하는 데이터 마이닝 기법은`
# #### 추정estimation

# %% [markdown]
# `미래의 양상을 예측하거나 미래 값을 추정한다는 것을 제외하면 분류나 추정과 동일한 의미를 갖고 있으며 장바구니분석/의사결정나무/신경망기법을 사용하는 데이터 마이닝 기법은`
# #### 예측predication

# %% [markdown]
# `같이 팔리는 물건처럼 아이템의 연관성을 파악하는 분석기법으로, 소매점이 물건배열계획, 카탈로그배열, 교차판매, 판촉행사 하는 등의 마케팅 계획 세우는 데도 사용되는 데이터마이닝기법은`
# #### 연관분석 association analysis

# %% [markdown]
# `연관분석의 한 기법인 장바구니 분석의 결과는 뭐로 나오나`
# #### 연관규칙

# %% [markdown]
# `이질적인 모집단을 동질성을 지닌 그룹별로 세분화하는 것을 의미하며, 선분류되어있는 기준에 의존하지 않는 비지도 학습이고, 데이터마이닝이나 모델링의 준비단계로서 사용되는 기법은`
# #### 군집분석clustering

# %% [markdown]
# `데이터 마이닝 5단계`
# - `목적정의->데이터준비->(1)->데이터마이닝->기법적용->검증`
# #### 데이터가공

# %% [markdown]
# `분류분석은 반응변수(종속변수)가 알려진 다변량 자료를 이용해 모형을 구축하여 새로운 자료에 대한 예측 및 분류를 수행하는 것이 목적인데`
# - `반응변수가 범주형->(1) 주목적`
# #### 분류가
# - `반응변수가 연속형->(2) 주목적`
# #### 예측이

# %% [markdown]
# `반응변수(종속변수)가 범주형인 경우 적용되는 회귀분석 모형은`
# #### 로지스틱 회귀분석

# %% [markdown]
# `인공신경망은 동물의 뇌신경계를 모방해 분류(또는 예측)을 위해 만들어진 모형.. 입력은 시냅스에 해당하며 개별신호의 강도에따라 가중되고, (1)는 인공신경망의 출력을 계산한다`.
# #### 활성화함수

# %% [markdown]
# `입력층이 은닉층 거치지 않고 직접 출력층에 연결되는 단층 신경망은`
# #### 퍼셉트론

# %% [markdown]
# `신경망의 활성 함수 중에서 표준화지수(또는 일반화 로지스틱)함수라고도 부르며, 출력값z가 여러개로 주어지고, 목표치가 다범주인 경우 각 범주에 속할 사후 확률을 제공하는 활성함수는 무엇인가`
# #### softmax 함수

# %% [markdown]
# `변수의 수가 많거나 입출력 변수 간에 복잡한 비선형 관계가 존재할 때 유용한 방법으로, 잡음에 민감하게 반응하지 않는 데이터 마이닝 기법은 무엇인가`
# #### 인공신경망ann

# %% [markdown]
# `신경망 모형에서 output을 결정하며, 선형 또는 곡선으로 출력해주는 것은 무엇인가`
# #### 활성화함수

# %% [markdown]
# `의사결정 나무는 상위노드로부터 하위노드로 나무구조를 형성하는 매 단계마다 분류 변수와 분류 기준값의 선택이 중요한데, 노드(집단) 내에서는 (1)이, 노드(집단) 간에는 (2)이 가장 커지도록 분기해야 한다`
# #### (1) 집단내 동질성 (2) 집단간 이질성

# %% [markdown]
# `의사 결정나무의 종류`
# - `목표변수가 이산형인 경우->(1)`
# #### 분류나무
# - `목표변수가 연속형인 경우->(2)`
# #### 회귀나무

# %% [markdown]
# `의사결정 나무 주요 알고리즘, 분류기준 변수의 선택법`
# - `CHAID다지분할 알고리즘: 분류나무이산형목표변수-카이제곱통계량, 회귀나무연속형목표변수- ANOVA f-통계량`
# - `CART이진분할 알고리즘: 분류이산-(1), 회귀연속-분산감소량`
# #### 분류이산-지니지수
# - `C4.5다지분할 알고리즘: 분류이산-(2), 회귀연속-없음`
# #### 분류이산-엔트로피지수
# > - 이진분할(Binary Split)
# > - 데이터를 두 개의 그룹으로 나누는 방식입니다.
# > - 한 번의 분할에서 오직 두 개의 하위 노드만 생성됩니다.
# > - 대표적인 알고리즘: CART(Classification and Regression Trees)
# > - 다지분할(Multiway Split)
# > - 데이터를 여러 개의 그룹으로 나누는 방식입니다.
# > - 한 번의 분할에서 세 개 이상의 하위 노드를 생성할 수 있습니다.
# > - 대표적인 알고리즘: CHAID(Chi-square Automatic Interaction Detector), C4.5

# %% [markdown]
# `분류기준값의 경계선 근방의 자료값에 대하여 오차가 클 수 있으며, 로지스틱 회귀와 같이 각 예측변수의 효과를 파악하기 어렵고, 새로운 자료에 대한 예측이 불안정할 수 있는 데이터마이닝 기법은`
# #### 의사결정나무

# %% [markdown]
# `여러 개의 분류모형에 의한 결과를 종합해 정확도를 높이는 방법은`
# #### 앙상블모형

# %% [markdown]
# `앙상블 기법 3가지`
# #### 배깅, 랜덤포레스트, 부스팅

# %% [markdown]
# `배깅 과정과 유사하나 붓스트랩 표본을 구성하는 재표본re-sampling 과정에서 각 자료에 동일한 확률을 부여하는 것이 아니라, 분류가 잘못된 데이터에 더 큰 가중을 주어 표본을 추출하는 방법은`
# #### 부스팅

# %% [markdown]
# `주어진 데이터에서만 높은 성과를 보이는 것으로, 매우 복잡한 신경망 모형을 사용해 학습오차를 매우 작게 한 경우 예측 오차가 매우 커지는 문제는`
# #### 오버피팅

# %% [markdown]
# `과적합 문제를 해결하기 위해 사용되는 추출방법 중 원천 데이터를 랜덤하게 두 분류로 분리해 교차 검정을 실시하는 방법으로, 훈련용 자료를 70%로 검증용 자료를 30%로 분할하는 방법은`
# #### 홀드아웃

# %% [markdown]
# `전체 데이터를 사이즈 동일한 K개의 하부집합subset으로 나누고, K번째의 하부집합을 검증용 자료로, 나머지k-1개는 훈련용 자료로 사용해 이를 k번 반복측정하고 각각의 반복측정 결과를 평균낸 값을 최종평가로 사용하는 방법은`
# #### k-fold 교차검증

# %% [markdown]
# `분류모형 평가방법 중 하나로, 목표 변수의 실제 범주와 모형에 의해 예측된 분류 범주 사이의 관계를 나타내는 표는`
# #### 오차분류표confusion matrix

# %% [markdown]
# `오차분류표에서 true로 예측한 관측치 중 실제값이 true인 정도를 나타내는 지표는 무엇인가`
# #### 정밀도precision

# %% [markdown]
# `오차분류표에서 실제값이 true인 관측치 중 예측치가 적중한 정도를 나타내는 것으로, 민감도와 동일한 지표는`
# #### 재현율recall=민감도

# %% [markdown]
# `오차분류표에서 정밀도와 재현율은 트레이드오프 관계(한지표가 높아지면 다른지표낮아질가능성 높음)이다. 이 효과를 보정하는데 사용하는 지표는`
# #### F1지표

# %% [markdown]
# `분류 모형의 평가 방법으로 레이더 이미지 분석의 성과를 측정하기 위해 개발된 것으로, X축은 fp ration(1-특이도), y축은 민감도로 두 값의 관계 평가하는 그래프는`
# #### ROC그래프

# %% [markdown]
# `ROC 그래프는 밑부분 면적이 넓을수록, 1에 가까울수록 좋은 모형이라고 평가된다. 이 밑부분 면적을 무엇이라 하는가`.
# #### AUC area under curve

# %% [markdown]
# `각 개체에 대해 관측된 여러 개의 변수 값들로부터 n개의 개체를 유사한 성격을 가지는 몇개의 군집으로 집단화하고 형성된 군집들의 특성을 파악해 군집들 사이의 관계를 분석하는 다변량 분석 기법이며, 별도의 반응변수가 요구되지 않는 비지도학습은 무엇`
# #### 군집분석

# %% [markdown]
# `계층적 군집을 형성하는 방법 중 작은 군집에서 군집을 병합해나가는 방법으로, 한 개의 항목으로 시작해 군집을 형성해 나가는 매 단계마다 모든 그룹쌍 간의 거리를 계산하고 가까운 순으로 병합을 수행하여 한 개 그룹만 남을 때까지 반복하는 방법은 무엇`
# #### 병합적방법

# %% [markdown]
# `군집 간의 병합 시 거리 측정(또는 병합)방법 5가지는`
# #### 최단연결법, 최장연결법, 중심연결법 평균연결법 와드연결법

# %% [markdown]
# `군집 간의 병합시 거리 측정(또는 병합)방법 중 군집 내의 오차제곱합에 기초해 군집을 수행하는 방법은 무엇`
# #### 와드연결법

# %% [markdown]
# `아래 데이터셋 a, b간의 유사성을 유클리드 거리로 계산하시오`
# - `a 키:180 몸무게:65`
# - `b 키:175 몸무게:70`
# #### 루트25=루트((180-175)제곱+(65-70)제곱)

# %% [markdown]
# `위의 데이터 a b 유사성을 맨해튼 거리로 계산하시오`
# #### 10=|180-175|+|65-70|

# %% [markdown]
# `군집의 수만큼(k개) 초기값을 지정하고 각 개체를 가까운 초기값에 할당해 군집을 형성한 뒤, 각 군집의 평균을 재계산하여 초기값을 갱신한 후 갱신된 값에 대해 위의 할당과정을 반복해 k개의 최종군집을 형성하는 방법은 무엇`
# #### k-평균 군집

# %% [markdown]
# `모형-기반(model-based)의 군집 방법 중 데이터가 k개의 모수적 모형의 가중합으로 표현되는 모집단 모형으로부터 나왔다는 가정하에서 모수와 함께 가중치를 자료로부터 추정하는 방법으로, 혼합 모형에서 모수와 가중치의 추정에 쓰이는 이 알고리즘은 무엇`
# #### EM알고리즘

# %% [markdown]
# `코호넨에 의해 제시 및 개발되어 코호넨 맵이라고도 부르며, 비지도 신경망에 해당하고 고차원 데이터를 이해하기 쉬운 저차원의 뉴런으로 정렬해 지도map의 형태로 형상화해 입력의 위치 관계를 그대로 보존하는 분석 방법은 무엇`
# #### SOM

# %% [markdown]
# `항목들 간의 조건-결과if-then식으로 표현되는 유용한 패턴 규칙을 발견해내는 것으로, 장바구니 분석 market based analysis라고도 부르는 이 분석은 무엇`
# #### 연관분석

# %% [markdown]
# `연관규칙의 측정 지표 중 품목 a가 포함된 거래 중에서 품목 a b를 동시에 포함하는 거래일 확률(a->b)를 통해 연관성 정도를 파악할 수 있는 지표는 무엇인가`
# #### 신뢰도

# %% [markdown]
# `연관규칙의 측정 지표에서 향상도가 두 품목이 서로 양의 관계를 가지고 있어 품목 b를 구매할 확률보다 품목 a를 구매하고 품목 b를 구매할 확률이 높다면 향상도 값은 얼마인가`
# #### 향상도>1

# %% [markdown]
# `시간에 따른 구매정보를 활용해 연관규칙을 발견하는 방법으로, 순차패턴이 연관규칙 a->b(품목a구매시 b도추후에구매)로 해석되는 분석은`
# #### 순차분석

# %% [markdown]
# `계층적 군집의 결과를 그린 그래프로, 군집간 구조적관계를 쉽게 살펴볼 수 있고 항목 및 군집 간의 거리를 알 수 있으며, 군집내의 항목간 유사정도를 파악함으로서 군집의 견고성을 해석할 수 있는 그래프는 무엇`
# #### 덴드로그램dendrogram

# %% [markdown]
# `의사결정 나무 중 연속형 타깃변수targetvar목표변수를 예측하는 의사결정 나무는`
# #### 회귀나무
