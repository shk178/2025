# %% [markdown]
# `빅데이터 분석에 경제성을 제공한 결정적인 기술은`

# %% [markdown]
# `데이터의 역할 중 암묵지 2가지는`

# %% [markdown]
# `데이터의 역할 중 형식지 2가지는`

# %% [markdown]
# `암묵지와 형식지의 상호작용 중 학습과 체험을 통해 겉으로 드러나지 않은 지식이나 무형의 지식을 개인이 습득하는 과정을 무엇이라고 하는가`

# %% [markdown]
# `암묵지와 형식지의 상호작용 중 내면화된 지식을 조직의 지식으로 만드는 과정을 무엇이라고 하는가`

# %% [markdown]
# `암묵지와 형식지의 상호작용 중 개인의 암묵지를 언어나 기호, 숫자 등의 형태로 나타내는 과정을 무엇이라고 하는가`

# %% [markdown]
# `암묵지와 형식지의 상호작용 중 표출화된 것을 다시 다른 개인이 본인의 지식에 연결하는 과정을 무엇이라 하는가`

# %% [markdown]
# `DIKW 피라미드에서 데이터의 가공/처리와 데이터 간 연간 관계 속에서 의미가 도출된 것으로, 의미가 유용하지 않을 수 있는 것을 무엇이라 하는가`

# %% [markdown]
# `DIKW 피라미드에서 데이터를 통해 도출된 다양한 정보를 구조화하여 유의미한 정보를 분류하고 개인적인 경험을 결합해 고유의 지식으로 내재화하는 것을 무엇이라 하는가`

# %% [markdown]
# `DIKW 피라미드에서 "상대적으로 저렴한 a마트에서 연필을 사야겠다."는 어디에 해당하는가`

# %% [markdown]
# `데이터베이스의 특징 4가지를 쓰시오`

# %% [markdown]
# `새로운 데이터 삽입/기존 데이터 삭제/갱신으로 항상 변화하면서도 현재의 정확한 데이터 유지해야 하는 것은 데이터베이스 어떤 특징인가`

# %% [markdown]
# `빅데이터 특징 3가지를 영어로 쓰시오`

# %% [markdown]
# `빅데이터 기능 중 구글 Ngram viewer는 어떤 역할 하는가`

# %% [markdown]
# `빅데이터는 어떤 본질적인 변화 만들어내는가-다음 항목을 빅데이터가 무엇으로 변화시켰는가 쓰시오`
# `사전처리 중심`
# `표본조사 중심`
# `질 중심`
# `인간관계 중심`

# %% [markdown]
# `빅데이터 활용사례 중 구글 검색 가능/월마트 매출 향상/질병 예후 진단과 같은 사례는 어느 사례에 해당하는가`

# %% [markdown]
# `기업내부의 데이터베이스 활용 시스템에 대한 설명이다. 알맞은 용어 쓰시오`
# `데이터 기반 의사결정을 지원하기 위한 리포트 중심의 도구`
# `호스트 컴퓨터와 온라인으로 접속된 여러 단말기 간의 처리 형태의 하나`
# `정보 위주의 분석 처리를 의미하며, 다양한 비즈니스 관점에서 쉽고 빠르게 다차원적인 데이터에 접근하여 의사 결정에 활용할 수 있는 정보를 얻게 해주는 기술`
# `고객관계관리라고 하며, 기업이 고객과 관련된 내외부 자료를 분석/통합해 고객 중심 자원을 극대화하고, 이를 토대로 고객 특성에 맞게 마케팅 활동을 계획/지원/평가하는 과정`
# `공급망 관리를 뜻하는 말로, 기업에서 원재료의 생산/유통 등 모든 공급망 단계를 최적화하여 수요자가 원하는 제품을 원하는 시간과 장소에 제공하는 것`
# `인사/재무/생산 등 기업의 전 부문에 걸쳐 독립적으로 운영되던 각종 관리 시스템의 경영 자원을 하나의 통합 시스템으로 재구축하여 생산성 극대화하는 경영 혁신 기법`

# %% [markdown]
# `빅데이터 활용 기본 테크닉`
# `어떤 변인들 간에 주목할 만한 상관관계 있는지 찾는법`
# `새로운 사건이 속하게 될 범주 찾는일`
# `최적화가 필요한 문제의 해결책을 자연선택/돌연변이 같은 메커니즘으로 점진적으로 진화시키는법`
# `훈련 데이터로부터 학습하여 알려진 특성을 활용해 예측하는데 초점`
# `독립변수 조작하여, 종속변수가 어떻게 변하는지 보면서 두 변인의 관계 파악`
# `특정 주제에 대해 말하거나 글을 쓴 사람의 감정 분석`
# `오피니언 리더, 즉 영향력 있는 사람 찾아낼 수 있으며 고객들 간 소셜 관계를 파악`

# %% [markdown]
# `빅데이터 위기 요인 3가지에 알맞는 해결책 쓰시오`
# `사생활 침해`
# `책임원칙 훼손`
# `데이터 오용`

# %% [markdown]
# `빅데이터 위기 요인 중 "빅데이터 기반 분석과 예측 기술 발전하면서 정확도가 증가한만큼 분석대상이 되는 사람들은 예측 알고리즘의 희생양이 될 가능성도 높아짐"은 어떤 요인인가`

# %% [markdown]
# `특정인의 성향에 따라 처벌하는 것 아닌 행동 결과를 보고 처벌해야 한다는 통제 방안은`

# %% [markdown]
# `싸이월드에는 OLAP 같은 분석 인프라가 존재하지 않았다 (오엑스)`

# %% [markdown]
# `데이터의 종류 중 음성, 텍스트, 이미지, 비디오와 같은 데이터를 무엇이라 하는가`

# %% [markdown]
# `데이터 사이언스의 구성 요소 3가지를 쓰시오`

# %% [markdown]
# `데이터 사이언스 3가지 영역은`
# `수학확률모델머신러닝분석학패턴인식과학습불확실성모델링`
# `시그널프로세싱프로그래밍데이터엔지니어링데이터웨어하우징고성능컴퓨팅`
# `커뮤니케이션프레젠테이션스토리텔링시각화`

# %% [markdown]
# `데이터사이언티스트 요구역량 2가지 쓰시오`

# %% [markdown]
# `데이터사이언티스트가 갖출 2가지 스킬은`
# `빅데이터이론적지식,데이터처리나분석기술과관련숙련된기술`
# `통찰력있는분석,설득력있는전달,다분야간협력`

# %% [markdown]
# `모델의 예측력 높이기 위해 인간을 바라보아야 하는 관점 3가지`

# %% [markdown]
# `가치 패러다임의 변화를 과거->현재->미래 순서로 쓰시오`

# %% [markdown]
# `데이터 양의 표시단위가 작은것에서 큰것 순서로 쓰시오`

# %% [markdown]
# `iot 시대가 되면서 수많은 물건에 센서가 부착되어 데이터가 끊임없이 생산된다. 이때 빅데이터 사업들은 iot를 통해 생산된 데이터를 저장해두고 이 데이터를 3rd party에 API를 통해 공개해 활용할 수 있다. 이러한 기능을 빅데이터의 ~기능이라고 한다`

# %% [markdown]
# `구글 번역 서비스에 활용된 빅데이터 특성은`

# %% [markdown]
# `빅데이터 시대가 도래하면서 발생할 수 있는 부정적인 측면 중 하나인 "책임원칙 훼손"은 범죄 예측 프로그램에 의거하여 범행 전에 예상 범죄자를 체포하는 것이다 (오엑스)`

# %% [markdown]
# `컴퓨터공학, 통계학, 수학 등의 학문적 지식은 물론 시각화 및 해커로서의 소양에 이르는 관련분야의 전문지식을 종합한 학문을 무엇이라 하는가`

# %% [markdown]
# `최대의 시청률을 얻으려면 어떤 프로그램을 어떤 시간대에 방송해야 하는가라는 문제 해결을 위해 사용하는 분석방법은`

# %% [markdown]
# `다음 데이터는 데이터의 종류 중 무엇에 해당하는가`
# `로그기록`
# `naver검색창에입력한키워드`
# `facebook댓글`
# `핸드폰셀카사진`
# `엑셀데이터`
# `iot센서`

# %% [markdown]
# `데이터베이스 구조와 제약조건에 관한 전반적인 명세를 의미하는 말로, 데이터베이스를 구성하는 데이터 속성, 관계 및 데이터 조작 시 데이터 값들이 갖는 제약조건을 정의한 것을 무엇이라 하는가`

# %% [markdown]
# `데이터에 포함된 식별 정보를 삭제하거나 알아볼 수 없는 형태로 변환하는 일을 뜻하는 말로, 가명, 일반화, 치환 등을 포함한 다양한 방법으로 구현하는 것은`

# %% [markdown]
# `데이터 사이언스는 통계학과 다른 접근법을 사용한다. 이 접근법은`

# %% [markdown]
# `주어진 비즈니스 문제를 해결하기 위해 사용되는 기법을 쓰시오`
# `맥주를 사는 사람은 콜라도 같이 구매하는 경우 많은가`
# `고객의 만족도가 충성도에 어떤 영향 미치는가`
# `친분관계가 승진에 어떤 영향 미치는가`
# `택배 차량을 어떻게 배치하는 것이 가장 비용효율적인가`
# `최대 시청률 얻으려면 어떤 프로그램을 어떤 시간대 방송해야하나`
# `커피를 사는 사람들은 브라우니를 사 먹는다`
# `월 100만원 이상 사용하는 고객은 어떤 특성 가진 집단에 속하는가`
# `a대학교 b학과 학생들 간 관계망은 어떻게 구성돼있는가`
# `은행에서 대출심사할 때 소득, 카드사용액, 나이 등 해당 고객의 개인적인 정보를 바탕으로 그 고객이 대출상환을 잘하는 집단에 속할지 그렇지 않은 집단에 속할지 예측할 수 있다`

# %% [markdown]
# `DKW 피라미드에서 상호 연결된 정보 패턴을 이해해 이를 토대로 예측한 결과물을 뭐라고 하는가`

# %% [markdown]
# `데이터베이스 내의 데이터에 대한 정확성 일관성 유효성 신뢰성을 보장하기 위해 데이터 변경 혹은 수정 시 여러가지 제한을 두어 데이터의 정확성 보증하는 것을 뭐라고 하는가`

# %% [markdown]
# `데이터베이스에 접근하는 언어를 뭐라고 하는가`

# %% [markdown]
# `데이터에 관한 구조화된 데이터로, 다른 데이터를 설명해주는 데이터를 뭐라고 하는가`

# %% [markdown]
# `데이터베이스 내 데이터를 신속하게 정렬하고 탐색하게 해주는 구조를 뭐라고 하는가`

# %% [markdown]
# `비즈니스 측면에서 일반적으로 "공동 활용 목적으로 구축된 유/무형의 구조물"을 의미한다. 각종 사용자 데이터나 M2M센서 등에서 수집된 데이터를 가공/처리/저장해두고 이 데이터에 접근할 수 있도록 API(application program interface)를 공개한다. 그러면 다양한 서드파티(3rd-party)사업자들이 비즈니스에 필요한 정보를 추출하여 활용할 수 있게 되고, 빅데이터는 그 자체로 이 역할을 수행한다`

# %% [markdown]
# `개인정보 비식별화 기법`
# `데이터의 길이, 유형, 형식과 같은 속성 유지한채, 새롭고 읽기쉬운 데이터를 익명으로 생성 기술`
# `개인정보 주체의 이름을 다른 이름으로 변경하는 기술`
# `데이터의 총합 값을 보임으로써 개별 데이터의 값을 보이지 않도록 함`
# `데이터 공유, 개방 목적에 따라 데이터셋에 구성된 값 중에 필요없는값 또는 개인식별에 중요한 값을 삭제`
# `데이터의 값을 범주의 값으로 변환해 값을 숨김`

# %% [markdown]
# `빅데이터 관련 기술`
# `대규모 분산 병렬 처리의 업계 표준으로 맵리듀스 시스템과 분산 파일 시스템인 HDFS로 구성된 플랫폼 기술이며, 선형적 성능과 용량확장성, 고장감내성 가진다`
# `실시간 분산형 컴퓨팅 플랫폼으로써 스칼라로 작성됐지만 스칼라/자바/파이썬/api를 지원한다. in-memory 방식으로 처리하기 때문에 하둡에비해 처리속도 빠르다`
# `공장 내 설비와 기계에 iot 설치돼 공정 데이터가 실시간 수집되고 데이터 기반 의사결정이 이루어짐으로써 생산성 극대화할 수 있다`
# `대규모로 저장된 데이터 안에서 체계적 자동적으로 통계적 규칙이나 패턴 분석해 가치있는 정보추출한다`
# `현재 정의된 목적이 없는 비정형 원시 데이터를 저장/대규모의 다양한 원시 데이터 세트를 기본 형식으로 저장하는 데이터 레포지토리 유형이다`
# `사용자 의사 결정에 도움주기 위해 기간시스템의 데이터베이스에 축적된 데이터를 공통의 형식으로 변환해 관리하는 데이터베이스이다`

# %% [markdown]
# `데이터웨어하우스 4가지특성`
